# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-02c6f6bb-cbb4-475a-862a-608d69663fe6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02c6f6bb-cbb4-475a-862a-608d69663fe6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"bayusulistiyawan","key":"ac683652beff2450b83ea3404d402ca1"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !ls ~/.kaggle
# Out:
# kaggle.json

# %%
# !kaggle datasets download -d madisona/translated-animals10

# !mkdir animals
# !unzip -qq translated-animals10.zip -d animals
# !ls animals
# Out:
# Downloading translated-animals10.zip to /content
#  98% 576M/586M [00:02<00:00, 206MB/s]
# 100% 586M/586M [00:03<00:00, 200MB/s]
# animals10

# %%
# !ls animals/animals10/raw-img/
# Out:
# butterfly  cat	chicken  cow  dog  elephant  horse  sheep  spider  squirrel

# %%
import os

animals = os.path.join('/content/animals/animals10/raw-img/')

print(os.listdir(animals))
# Out:
# ['squirrel', 'sheep', 'chicken', 'elephant', 'dog', 'cat', 'butterfly', 'cow', 'horse', 'spider']

# %%
import shutil

ignore_animals = ['squirrel','sheep','cat', 'elephant', 'cow','horse']

for x in ignore_animals:
  path = os.path.join(animals, x)
  shutil.rmtree(path)

# %%
list_animals = os.listdir(animals)
print(list_animals)
# Out:
# ['chicken', 'dog', 'butterfly', 'spider']

# %%
from PIL import Image
total = 0

for x in list_animals:
  dir = os.path.join(animals, x)
  y = len(os.listdir(dir))
  print(x+':', y)
  total = total + y
  
  img_name = os.listdir(dir)
  for z in range(4):
    img_path = os.path.join(dir, img_name[z])
    img = Image.open(img_path)
    print('-',img.size)
  print('---------------')

print('\nTotal :', total)
# Out:
# chicken: 3098
# - (300, 225)
# - (300, 225)
# - (300, 225)
# - (300, 225)
# ---------------
# dog: 4863
# - (300, 294)
# - (300, 264)
# - (299, 300)
# - (300, 251)
# ---------------
# butterfly: 2112
# - (640, 428)
# - (300, 225)
# - (640, 426)
# - (300, 169)
# ---------------
# spider: 4821
# - (300, 235)
# - (277, 300)
# - (300, 240)
# - (300, 199)
# ---------------
#
# Total : 14894

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 2, figsize=(15,15))
fig.suptitle("Randomly displays images.", fontsize=24)
animals_sorted = sorted(list_animals)
animals_id = 0
for i in range(2):
  for j in range(2):
    try:
      animals_selected = animals_sorted[animals_id] 
      animals_id += 1
    except:
      break
    if animals_selected == '.TEMP':
        continue
    animals_selected_images = os.listdir(os.path.join(animals, animals_selected))
    animals_selected_random = np.random.choice(animals_selected_images)
    img = plt.imread(os.path.join(animals, animals_selected, animals_selected_random))
    ax[i][j].imshow(img)
    ax[i][j].set_title(animals_selected, pad=10, fontsize=22)
    
plt.setp(ax, xticks=[],yticks=[])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    rescale=1/255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2   
)

# %%
batch_size = 256

data_train = train_datagen.flow_from_directory(
    animals,
    target_size=(150, 150),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

data_val = train_datagen.flow_from_directory(
    animals, 
    target_size=(150, 150),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 11917 images belonging to 4 classes.
# Found 2977 images belonging to 4 classes.

# %%
import tensorflow as tf
# from tensorflow.keras import applications, optimizers

tf.device('/device:GPU:0')

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5), 
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 3,473,988
# Trainable params: 3,473,988
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.92 and logs.get('val_accuracy')>0.92):
      print("\nAccuracy above 92%, finish training!")
      self.model.stop_training = True

callbacks = myCallback()

# %%
history = model.fit(data_train, 
                    epochs = 100, 
                    steps_per_epoch = data_train.samples // batch_size,
                    validation_data = data_val, 
                    validation_steps = data_val.samples // batch_size,
                    verbose = 1,
                    callbacks = [callbacks])
# Out:
# Epoch 1/100
# 46/46 [==============================] - 116s 2s/step - loss: 1.3042 - accuracy: 0.3857 - val_loss: 1.1599 - val_accuracy: 0.4624
# Epoch 2/100
# 46/46 [==============================] - 81s 2s/step - loss: 1.1053 - accuracy: 0.5112 - val_loss: 1.0699 - val_accuracy: 0.5437
# Epoch 3/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.9817 - accuracy: 0.5891 - val_loss: 0.9501 - val_accuracy: 0.6062
# Epoch 4/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.8583 - accuracy: 0.6547 - val_loss: 0.8101 - val_accuracy: 0.6893
# Epoch 5/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.7788 - accuracy: 0.6971 - val_loss: 0.7647 - val_accuracy: 0.6882
# Epoch 6/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.7331 - accuracy: 0.7112 - val_loss: 0.7254 - val_accuracy: 0.7180
# Epoch 7/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.6753 - accuracy: 0.7401 - val_loss: 0.6460 - val_accuracy: 0.7628
# Epoch 8/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.6189 - accuracy: 0.7673 - val_loss: 0.5853 - val_accuracy: 0.7834
# Epoch 9/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.6151 - accuracy: 0.7680 - val_loss: 0.6158 - val_accuracy: 0.7688
# Epoch 10/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.5733 - accuracy: 0.7842 - val_loss: 0.5417 - val_accuracy: 0.7983
# Epoch 11/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.5485 - accuracy: 0.7950 - val_loss: 0.5249 - val_accuracy: 0.7994
# Epoch 12/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.5153 - accuracy: 0.8056 - val_loss: 0.5115 - val_accuracy: 0.8036
# Epoch 13/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.5084 - accuracy: 0.8096 - val_loss: 0.4969 - val_accuracy: 0.8157
# Epoch 14/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.4870 - accuracy: 0.8185 - val_loss: 0.4901 - val_accuracy: 0.8217
# Epoch 15/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.4847 - accuracy: 0.8223 - val_loss: 0.5225 - val_accuracy: 0.8082
# Epoch 16/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.4537 - accuracy: 0.8385 - val_loss: 0.4852 - val_accuracy: 0.8239
# Epoch 17/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.4402 - accuracy: 0.8417 - val_loss: 0.4520 - val_accuracy: 0.8413
# Epoch 18/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.4560 - accuracy: 0.8339 - val_loss: 0.5085 - val_accuracy: 0.8161
# Epoch 19/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.4549 - accuracy: 0.8359 - val_loss: 0.4728 - val_accuracy: 0.8235
# Epoch 20/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.4220 - accuracy: 0.8465 - val_loss: 0.3975 - val_accuracy: 0.8597
# Epoch 21/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.4043 - accuracy: 0.8486 - val_loss: 0.4044 - val_accuracy: 0.8544
# Epoch 22/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3969 - accuracy: 0.8565 - val_loss: 0.4265 - val_accuracy: 0.8416
# Epoch 23/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.4154 - accuracy: 0.8492 - val_loss: 0.3954 - val_accuracy: 0.8580
# Epoch 24/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3950 - accuracy: 0.8562 - val_loss: 0.3619 - val_accuracy: 0.8665
# Epoch 25/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3826 - accuracy: 0.8614 - val_loss: 0.3942 - val_accuracy: 0.8562
# Epoch 26/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.4030 - accuracy: 0.8519 - val_loss: 0.3896 - val_accuracy: 0.8622
# Epoch 27/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3728 - accuracy: 0.8660 - val_loss: 0.3954 - val_accuracy: 0.8612
# Epoch 28/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3725 - accuracy: 0.8641 - val_loss: 0.3765 - val_accuracy: 0.8690
# Epoch 29/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3573 - accuracy: 0.8709 - val_loss: 0.3501 - val_accuracy: 0.8739
# Epoch 30/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3513 - accuracy: 0.8749 - val_loss: 0.3590 - val_accuracy: 0.8700
# Epoch 31/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3521 - accuracy: 0.8708 - val_loss: 0.3647 - val_accuracy: 0.8672
# Epoch 32/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3426 - accuracy: 0.8724 - val_loss: 0.3970 - val_accuracy: 0.8544
# Epoch 33/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3468 - accuracy: 0.8742 - val_loss: 0.3843 - val_accuracy: 0.8576
# Epoch 34/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.3406 - accuracy: 0.8780 - val_loss: 0.3538 - val_accuracy: 0.8704
# Epoch 35/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3315 - accuracy: 0.8808 - val_loss: 0.3219 - val_accuracy: 0.8896
# Epoch 36/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3253 - accuracy: 0.8824 - val_loss: 0.3418 - val_accuracy: 0.8803
# Epoch 37/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3201 - accuracy: 0.8841 - val_loss: 0.3362 - val_accuracy: 0.8842
# Epoch 38/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3141 - accuracy: 0.8859 - val_loss: 0.3605 - val_accuracy: 0.8697
# Epoch 39/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3191 - accuracy: 0.8857 - val_loss: 0.3394 - val_accuracy: 0.8807
# Epoch 40/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2988 - accuracy: 0.8920 - val_loss: 0.3208 - val_accuracy: 0.8864
# Epoch 41/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3083 - accuracy: 0.8898 - val_loss: 0.3192 - val_accuracy: 0.8881
# Epoch 42/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.3089 - accuracy: 0.8877 - val_loss: 0.3392 - val_accuracy: 0.8757
# Epoch 43/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2931 - accuracy: 0.8920 - val_loss: 0.3674 - val_accuracy: 0.8743
# Epoch 44/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2909 - accuracy: 0.8959 - val_loss: 0.3154 - val_accuracy: 0.8920
# Epoch 45/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.3151 - accuracy: 0.8867 - val_loss: 0.3132 - val_accuracy: 0.8885
# Epoch 46/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2961 - accuracy: 0.8922 - val_loss: 0.3114 - val_accuracy: 0.8913
# Epoch 47/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.2959 - accuracy: 0.8922 - val_loss: 0.3197 - val_accuracy: 0.8896
# Epoch 48/100
# 46/46 [==============================] - 84s 2s/step - loss: 0.2767 - accuracy: 0.9021 - val_loss: 0.3034 - val_accuracy: 0.8910
# Epoch 49/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2819 - accuracy: 0.8993 - val_loss: 0.3264 - val_accuracy: 0.8881
# Epoch 50/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2772 - accuracy: 0.8996 - val_loss: 0.3253 - val_accuracy: 0.8810
# Epoch 51/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.2833 - accuracy: 0.8993 - val_loss: 0.3103 - val_accuracy: 0.8935
# Epoch 52/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.2875 - accuracy: 0.8978 - val_loss: 0.3099 - val_accuracy: 0.8928
# Epoch 53/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2735 - accuracy: 0.9019 - val_loss: 0.3285 - val_accuracy: 0.8849
# Epoch 54/100
# 46/46 [==============================] - 84s 2s/step - loss: 0.2668 - accuracy: 0.9023 - val_loss: 0.3155 - val_accuracy: 0.8963
# Epoch 55/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2781 - accuracy: 0.8970 - val_loss: 0.2994 - val_accuracy: 0.8952
# Epoch 56/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2745 - accuracy: 0.9032 - val_loss: 0.3144 - val_accuracy: 0.8896
# Epoch 57/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2759 - accuracy: 0.9022 - val_loss: 0.3014 - val_accuracy: 0.8960
# Epoch 58/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2741 - accuracy: 0.9006 - val_loss: 0.3249 - val_accuracy: 0.8956
# Epoch 59/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2532 - accuracy: 0.9093 - val_loss: 0.2963 - val_accuracy: 0.9045
# Epoch 60/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2802 - accuracy: 0.8982 - val_loss: 0.3063 - val_accuracy: 0.8931
# Epoch 61/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2564 - accuracy: 0.9085 - val_loss: 0.2993 - val_accuracy: 0.8988
# Epoch 62/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2510 - accuracy: 0.9086 - val_loss: 0.3011 - val_accuracy: 0.8960
# Epoch 63/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2485 - accuracy: 0.9103 - val_loss: 0.2789 - val_accuracy: 0.9073
# Epoch 64/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2497 - accuracy: 0.9115 - val_loss: 0.2949 - val_accuracy: 0.8974
# Epoch 65/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2364 - accuracy: 0.9154 - val_loss: 0.2825 - val_accuracy: 0.8981
# Epoch 66/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2374 - accuracy: 0.9154 - val_loss: 0.3355 - val_accuracy: 0.8810
# Epoch 67/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2468 - accuracy: 0.9089 - val_loss: 0.2906 - val_accuracy: 0.8952
# Epoch 68/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.2404 - accuracy: 0.9150 - val_loss: 0.2922 - val_accuracy: 0.8970
# Epoch 69/100
# 46/46 [==============================] - 79s 2s/step - loss: 0.2331 - accuracy: 0.9164 - val_loss: 0.2814 - val_accuracy: 0.9052
# Epoch 70/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.2273 - accuracy: 0.9182 - val_loss: 0.2992 - val_accuracy: 0.8952
# Epoch 71/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2403 - accuracy: 0.9121 - val_loss: 0.3097 - val_accuracy: 0.8885
# Epoch 72/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2222 - accuracy: 0.9196 - val_loss: 0.3008 - val_accuracy: 0.8956
# Epoch 73/100
# 46/46 [==============================] - 82s 2s/step - loss: 0.2297 - accuracy: 0.9161 - val_loss: 0.2919 - val_accuracy: 0.9013
# Epoch 74/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2249 - accuracy: 0.9197 - val_loss: 0.2744 - val_accuracy: 0.9084
# Epoch 75/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2305 - accuracy: 0.9162 - val_loss: 0.2723 - val_accuracy: 0.9070
# Epoch 76/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2224 - accuracy: 0.9212 - val_loss: 0.2957 - val_accuracy: 0.8977
# Epoch 77/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2317 - accuracy: 0.9163 - val_loss: 0.2688 - val_accuracy: 0.9080
# Epoch 78/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2161 - accuracy: 0.9204 - val_loss: 0.2914 - val_accuracy: 0.9020
# Epoch 79/100
# 46/46 [==============================] - 83s 2s/step - loss: 0.2185 - accuracy: 0.9213 - val_loss: 0.2927 - val_accuracy: 0.9027
# Epoch 80/100
# 46/46 [==============================] - 82s 2s/step - loss: 0.2427 - accuracy: 0.9097 - val_loss: 0.2881 - val_accuracy: 0.9027
# Epoch 81/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2267 - accuracy: 0.9202 - val_loss: 0.2747 - val_accuracy: 0.9055
# Epoch 82/100
# 46/46 [==============================] - 82s 2s/step - loss: 0.2118 - accuracy: 0.9249 - val_loss: 0.2667 - val_accuracy: 0.9123
# Epoch 83/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2106 - accuracy: 0.9228 - val_loss: 0.2978 - val_accuracy: 0.8999
# Epoch 84/100
# 46/46 [==============================] - 82s 2s/step - loss: 0.2264 - accuracy: 0.9191 - val_loss: 0.2641 - val_accuracy: 0.9094
# Epoch 85/100
# 46/46 [==============================] - 82s 2s/step - loss: 0.2057 - accuracy: 0.9257 - val_loss: 0.2936 - val_accuracy: 0.8984
# Epoch 86/100
# 46/46 [==============================] - 82s 2s/step - loss: 0.2038 - accuracy: 0.9252 - val_loss: 0.2747 - val_accuracy: 0.9052
# Epoch 87/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2102 - accuracy: 0.9235 - val_loss: 0.3020 - val_accuracy: 0.8974
# Epoch 88/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2144 - accuracy: 0.9227 - val_loss: 0.2751 - val_accuracy: 0.9080
# Epoch 89/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2067 - accuracy: 0.9238 - val_loss: 0.2951 - val_accuracy: 0.8999
# Epoch 90/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2064 - accuracy: 0.9276 - val_loss: 0.2913 - val_accuracy: 0.9031
# Epoch 91/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2140 - accuracy: 0.9213 - val_loss: 0.2893 - val_accuracy: 0.9045
# Epoch 92/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2023 - accuracy: 0.9270 - val_loss: 0.2827 - val_accuracy: 0.9016
# Epoch 93/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.1977 - accuracy: 0.9278 - val_loss: 0.2540 - val_accuracy: 0.9134
# Epoch 94/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.2092 - accuracy: 0.9251 - val_loss: 0.3310 - val_accuracy: 0.8846
# Epoch 95/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2008 - accuracy: 0.9280 - val_loss: 0.2523 - val_accuracy: 0.9109
# Epoch 96/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.1870 - accuracy: 0.9299 - val_loss: 0.2851 - val_accuracy: 0.9062
# Epoch 97/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.1941 - accuracy: 0.9290 - val_loss: 0.2639 - val_accuracy: 0.9080
# Epoch 98/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.1981 - accuracy: 0.9287 - val_loss: 0.2628 - val_accuracy: 0.9119
# Epoch 99/100
# 46/46 [==============================] - 80s 2s/step - loss: 0.1915 - accuracy: 0.9294 - val_loss: 0.3195 - val_accuracy: 0.8910
# Epoch 100/100
# 46/46 [==============================] - 81s 2s/step - loss: 0.2102 - accuracy: 0.9229 - val_loss: 0.2759 - val_accuracy: 0.9052

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with tf.io.gfile.GFile('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpfkuh398t/assets

# %%
# !ls -la | grep 'model'
# Out:
# -rw-r--r-- 1 root root  13900684 Jun 27 15:35 model.tflite
